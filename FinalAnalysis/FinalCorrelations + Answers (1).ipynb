# %% [markdown]
# ### Overall
#
# Here we can see the graph showing the amount of special genres by each year.
# We decided to divide by the amount of movies in a particular decade to get better results of quantity.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from pyspark.sql import Row

df = sqlContext.createDataFrame(sc.parallelize([
  Row(category="Drama", sentiment = 5294.242300000068, year=1930, amount=0.1853210766133305),
  Row(category="Comedy", sentiment = 5294.242300000068, year=1930, amount=0.17297605171134894),
  Row(category="Romance", sentiment = 5294.242300000068, year=1930, amount=0.05700964289498781),
  Row(category="Crime", sentiment = 5294.242300000068, year=1930, amount=0.03318056585779379),
  Row(category="Action", sentiment = 5294.242300000068, year=1930, amount=0.026557698421108403),

  Row(category="Drama", sentiment = 3467.3983999999605, year=1960, amount=0.18676513697270003),
  Row(category="Comedy", sentiment = 3467.3983999999605, year=1960, amount=0.13524032869665534),
  Row(category="Romance", sentiment = 3467.3983999999605, year=1960, amount=0.04429650783444128),
  Row(category="Crime", sentiment = 3467.3983999999605, year=1960, amount=0.04402038751406606),
  Row(category="Action", sentiment = 3467.3983999999605, year=1960, amount=0.024343977834724966),
  
  Row(category="Drama", sentiment = 5333.998900000031, year=1990, amount=0.20494107802901546),
  Row(category="Comedy", sentiment = 5333.998900000031, year=1990, amount=0.1495269803574616),
  Row(category="Romance", sentiment = 5333.998900000031, year=1990, amount=0.09595783214558097),
  Row(category="Crime", sentiment = 5333.998900000031, year=1990, amount=0.03268135712083466),
  Row(category="Action", sentiment = 5333.998900000031, year=1990, amount=0.034299127335377946),
    
  Row(category="Drama", sentiment = 4738.24, year=2000, amount=0.1783095236245602),
  Row(category="Comedy", sentiment = 4738.24, year=2000, amount=0.14526608538179234),
  Row(category="Romance", sentiment = 4738.24, year=2000, amount=0.06039386542510107),
  Row(category="Crime", sentiment = 4738.24, year=2000, amount=0.027207447977547348),
  Row(category="Action", sentiment = 4738.24, year=2000, amount=0.02932263552565164),
    
])).toPandas()    

sns.pairplot(x_vars=["category"], y_vars=["amount"], data=df, hue="year", height=5)

# %% [markdown]
# ### Drama
#
# This is a correlation between Drama genre and years sentiment analysis.
# As we can see, sentiment does not build any good correlations with this genre

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from pyspark.sql import Row

df = sqlContext.createDataFrame(sc.parallelize([
  Row(category="Drama", sentiment = 5294.242300000068, year=1930, amount=0.1853210766133305),

  Row(category="Drama", sentiment = 3467.3983999999605, year=1960, amount=0.18676513697270003),
  
  Row(category="Drama", sentiment = 5333.998900000031, year=1990, amount=0.20494107802901546),

  Row(category="Drama", sentiment = 4738.24, year=2000, amount=0.1783095236245602),

    
])).toPandas()    

sns.pairplot(x_vars=["sentiment"], y_vars=["amount"], data=df, hue="year", height=5)

# %% [markdown]
# ### Comedy
#
# This is a correlation between Comedy genre and years sentiment analysis.
# We can imagine that there is a little bit of connection with sentiment because the more sentiment, the more comedy movies are in cinema as graph shows.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from pyspark.sql import Row

df = sqlContext.createDataFrame(sc.parallelize([
  Row(category="Comedy", sentiment = 5294.242300000068, year=1930, amount=0.17297605171134894),
    
  Row(category="Comedy", sentiment = 3467.3983999999605, year=1960, amount=0.13524032869665534),
    
  Row(category="Comedy", sentiment = 5333.998900000031, year=1990, amount=0.1495269803574616),
    
  Row(category="Comedy", sentiment = 4738.24, year=2000, amount=0.14526608538179234),

])).toPandas()    

sns.pairplot(x_vars=["sentiment"], y_vars=["amount"], data=df, hue="year", height=5)

# %% [markdown]
# ### Romance
#
# This is a correlation between Romance genre and years sentiment analysis.
# We can actually claim the connection. If we consider only sentiment analysis and movies genre in our analysis, there is a connection -> happier people -> more romance movies.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from pyspark.sql import Row

df = sqlContext.createDataFrame(sc.parallelize([

  Row(category="Romance", sentiment = 5294.242300000068, year=1930, amount=0.05700964289498781),

  Row(category="Romance", sentiment = 3467.3983999999605, year=1960, amount=0.04429650783444128),

  Row(category="Romance", sentiment = 5333.998900000031, year=1990, amount=0.09595783214558097),

  Row(category="Romance", sentiment = 4738.24, year=2000, amount=0.06039386542510107),
    
])).toPandas()    

sns.pairplot(x_vars=["sentiment"], y_vars=["amount"], data=df, hue="year", height=5)

# %% [markdown]
# ### Crime
#
# This is a correlation between Crime genre and years sentiment analysis.
# We don't think that there is a correlation between them.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from pyspark.sql import Row

df = sqlContext.createDataFrame(sc.parallelize([

  Row(category="Crime", sentiment = 5294.242300000068, year=1930, amount=0.03318056585779379),

  Row(category="Crime", sentiment = 3467.3983999999605, year=1960, amount=0.04402038751406606),
  
  Row(category="Crime", sentiment = 5333.998900000031, year=1990, amount=0.03268135712083466),

  Row(category="Crime", sentiment = 4738.24, year=2000, amount=0.027207447977547348),
    
])).toPandas()    

sns.pairplot(x_vars=["sentiment"], y_vars=["amount"], data=df, hue="year", height=5)

# %% [markdown]
# ### Action
#
# This is a correlation between Action genre and years sentiment analysis.
# From 60s we can see the correlation, almost a linear one.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from pyspark.sql import Row

df = sqlContext.createDataFrame(sc.parallelize([

  Row(category="Action", sentiment = 5294.242300000068, year=1930, amount=0.026557698421108403),

  Row(category="Action", sentiment = 3467.3983999999605, year=1960, amount=0.024343977834724966),
  
  Row(category="Action", sentiment = 5333.998900000031, year=1990, amount=0.034299127335377946),

  Row(category="Action", sentiment = 4738.24, year=2000, amount=0.02932263552565164),
    
])).toPandas()    

sns.pairplot(x_vars=["sentiment"], y_vars=["amount"], data=df, hue="year", height=5)
